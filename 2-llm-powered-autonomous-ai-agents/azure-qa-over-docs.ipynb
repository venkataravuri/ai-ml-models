# %%
# !pip install --quiet langchain openai python-dotenv sentence_transformers chromadb tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 62.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
# !wget https://raw.githubusercontent.com/hwchase17/langchain/master/docs/extras/modules/state_of_the_union.txt
# Out:
# --2023-07-05 04:10:20--  https://raw.githubusercontent.com/hwchase17/langchain/master/docs/extras/modules/state_of_the_union.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39027 (38K) [text/plain]
# Saving to: ‘state_of_the_union.txt’
#
# state_of_the_union. 100%[===================>]  38.11K  --.-KB/s    in 0.005s
#
# 2023-07-05 04:10:20 (7.29 MB/s) - ‘state_of_the_union.txt’ saved [39027/39027]

# %%
import os

os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["OPENAI_API_BASE"] = "https://genieopenai.openai.azure.com/"
os.environ["OPENAI_API_KEY"] = "314b64c2161149e7be836e8dcb6804f2"
os.environ["OPENAI_API_VERSION"] = "2022-12-01"

# %%
from langchain.chains import RetrievalQA
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import AzureOpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains.question_answering import load_qa_chain

# %%
embeddings = HuggingFaceEmbeddings()
text = "I love dog"
query_result = embeddings.embed_query(text)
doc_result = embeddings.embed_documents([text])

# %%
embeddings.model_name
# Out:
# 'sentence-transformers/all-mpnet-base-v2'

# %%
llm = AzureOpenAI(
    deployment_name="venkat-text-davinci",
    model_name="text-davinci-003",
)
print(llm("Hi"))
# Out:
# ,
#
# I am trying to use the search API to get a list of all public pages on Facebook. I am using the following code:
#
# $search_url = 'https://graph.facebook.com/search?q=pages&type=page&access_token='.$page_access_token;
#
# $results = json_decode(file_get_contents($search_url));
#
# foreach($results->data as $page){
#    echo $page->name;
# }
#
# But this only returns a limited number of pages (the first few that appear in the search results). Is there a way to get a list of all public pages on Facebook?
#
# Thanks!

# %%
from langchain.document_loaders.onedrive_file import CHUNK_SIZE
loader = TextLoader("/content/state_of_the_union.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(documents)

# embeddings = OpenAIEmbeddings()
embeddings = HuggingFaceEmbeddings()
docsearch = Chroma.from_documents(texts, embeddings)

# %%
docsearch.get(ids=['f2e2babc-1ae9-11ee-b3e0-0242ac1c000c'], include=['documents', 'embeddings', 'metadatas'])

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query)
docs
# Out:
# [Document(page_content='Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections. \n\nTonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service. \n\nOne of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court. \n\nAnd I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.', metadata={'source': '/content/state_of_the_union.txt'}),
# ...

# %%
chain = load_qa_chain(llm, chain_type="stuff")
query = "What did the president say about Ketanji Brown Jackson"
chain.run(input_documents=docs, question=query)
# Out:
# " The president said that Ketanji Brown Jackson is one of the nation's top legal minds, a former top litigator in private practice, a former federal public defender, from a family of public school educators and police officers, and a consensus builder. He also said that she has received a broad range of support from the Fraternal Order of Police to former judges appointed by Democrats and Republicans."

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever())

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="map_reduce", retriever=docsearch.as_retriever())

# %%
from langchain.prompts import PromptTemplate
prompt_template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
Answer in Italian:"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %%
chain_type_kwargs = {"prompt": PROMPT}
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever(), chain_type_kwargs=chain_type_kwargs, return_source_documents=True)

# %%
query = "What did the president say about Ketanji Brown Jackson"
#result = qa.run(query)
result = qa({"query": query})
result["result"], result["source_documents"]
# Out:
# (' Il presidente ha detto che Ketanji Brown Jackson è una delle più grandi menti legali del paese, che continuerà il patrimonio di eccellenza di Justice Breyer e che ha ricevuto un ampio sostegno, da Fraternal Order of Police a ex giudici designati da democratici e repubblicani.',
# ...
