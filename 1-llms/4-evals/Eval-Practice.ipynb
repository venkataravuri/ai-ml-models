# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 10423, done.
# remote: Counting objects: 100% (2968/2968), done.
# remote: Compressing objects: 100% (415/415), done.
# remote: Total 10423 (delta 2647), reused 2662 (delta 2537), pack-reused 7455
# Receiving objects: 100% (10423/10423), 12.35 MiB | 8.44 MiB/s, done.
# Resolving deltas: 100% (6901/6901), done.

# %%
# %cd lm-evaluation-harness
# Out:
# /content/lm-evaluation-harness

# %%
# %pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/lm-evaluation-harness
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 97.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 16.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %pip install tensorrt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1-py2.py3-none-any.whl size=16973 sha256=b10c5ef839cc12ff18f132ab8d42ca828677820c2c058551a97f8a64f06600ee
#   Stored in directory: /root/.cache/pip/wheels/6d/29/56/abdffd4c604f255b5254bef3f1c598ab7811ea020540599438
# Successfully built tensorrt
# ...

# %%
# %%python main.py --model EleutherAI/gpt-j-6B --tasks hellaswag --device cuda:0
# Out:
# 2023-05-29 06:29:59.750286: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/lm-evaluation-harness/main.py:7 in <module>                         │
# │                                                                              │
# │     4 import fnmatch                                                         │
# │     5 import os                                                              │
# │     6                                                                        │
# │ ❱   7 from lm_eval import tasks, evaluator                                   │
# │     8                                                                        │
# │     9 logging.getLogger("openai").setLevel(logging.WARNING)                  │
# │    10                                                                        │
# ...
