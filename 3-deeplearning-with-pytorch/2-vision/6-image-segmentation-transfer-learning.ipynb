# %% [markdown]
# # Pytorch Instance Segmentation Transfer Learning

# %%
import torch
import torchvision
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision import transforms, utils
from torchvision.models.detection import FasterRCNN, MaskRCNN
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from sklearn.metrics import roc_auc_score, f1_score
import glob
import numpy as np
import cv2
import os
import csv
import copy
import time
from tqdm import tqdm

# %%
import os.path
if not os.path.isfile('crackforest.zip'):
  # !wget https://github.com/msminhas93/DeepLabv3FineTuning/archive/master.zip -O crackforest.zip
  # !unzip crackforest.zip 'DeepLabv3FineTuning-master/CrackForest/*' -j -d CrackForest
  # !mv CrackForest/DeepLabv3FineTuning-master/CrackForest/* CrackForest/
  # !rm -rf CrackForest/DeepLabv3FineTuning-master
# Out:
# --2019-09-29 10:28:24--  https://github.com/msminhas93/DeepLabv3FineTuning/archive/master.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/msminhas93/DeepLabv3FineTuning/zip/master [following]
# --2019-09-29 10:28:24--  https://codeload.github.com/msminhas93/DeepLabv3FineTuning/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.121
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘crackforest.zip’
#
# crackforest.zip         [  <=>               ]   3.92M  18.7MB/s    in 0.2s
#
# 2019-09-29 10:28:25 (18.7 MB/s) - ‘crackforest.zip’ saved [4105589]
#
# Archive:  crackforest.zip
# 79c4c1cd5a345033a9fc2e5f555ac6bd64d89166
#    creating: CrackForest/DeepLabv3FineTuning-master/CrackForest/
#    creating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/001.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/002.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/003.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/004.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/005.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/006.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/007.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/008.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/009.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/010.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/011.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/012.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/013.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/014.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/015.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/016.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/017.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/018.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/019.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/020.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/021.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/022.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/023.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/024.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/025.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/026.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/027.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/028.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/029.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/030.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/031.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/032.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/033.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/034.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/035.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/036.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/037.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/038.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/039.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/040.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/041.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/042.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/043.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/044.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/045.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/046.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/047.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/048.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/049.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/050.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/051.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/052.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/053.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/054.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/055.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/056.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/057.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/058.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/059.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/060.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/061.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/062.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/063.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/064.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/065.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/066.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/067.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/068.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/069.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/070.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/071.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/072.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/073.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/074.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/075.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/076.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/077.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/078.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/079.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/080.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/081.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/082.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/083.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/084.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/085.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/086.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/087.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/088.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/089.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/090.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/091.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/092.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/093.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/094.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/095.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/096.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/097.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/098.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/099.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/100.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/101.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/102.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/103.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/104.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/105.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/106.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/107.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/108.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/109.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/110.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/111.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/112.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/113.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/114.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/115.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/116.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/117.jpg
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Images/118.jpg
#    creating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/001_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/002_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/003_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/004_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/005_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/006_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/007_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/008_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/009_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/010_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/011_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/012_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/013_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/014_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/015_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/016_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/017_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/018_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/019_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/020_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/021_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/022_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/023_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/024_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/025_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/026_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/027_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/028_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/029_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/030_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/031_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/032_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/033_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/034_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/035_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/036_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/037_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/038_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/039_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/040_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/041_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/042_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/043_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/044_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/045_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/046_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/047_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/048_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/049_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/050_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/051_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/052_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/053_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/054_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/055_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/056_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/057_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/058_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/059_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/060_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/061_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/062_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/063_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/064_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/065_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/066_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/067_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/068_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/069_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/070_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/071_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/072_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/073_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/074_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/075_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/076_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/077_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/078_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/079_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/080_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/081_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/082_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/083_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/084_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/085_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/086_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/087_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/088_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/089_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/090_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/091_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/092_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/093_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/094_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/095_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/096_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/097_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/098_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/099_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/100_label.PNG
#  extracting: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/101_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/102_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/103_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/104_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/105_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/106_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/107_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/108_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/109_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/110_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/111_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/112_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/113_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/114_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/115_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/116_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/117_label.PNG
#   inflating: CrackForest/DeepLabv3FineTuning-master/CrackForest/Masks/118_label.PNG
# caution: filename not matched:  -j

# %%
data_dir = "CrackForest"
bpath = "models"
epochs = 5
batchsize = 4

# %%
# Define few transformations for the Segmentation Dataloader

class Resize(object):
    """Resize image and/or masks."""

    def __init__(self, imageresize, maskresize):
        self.imageresize = imageresize
        self.maskresize = maskresize

    def __call__(self, sample):
        image, mask = sample['image'], sample['mask']
        if len(image.shape) == 3:
            image = image.transpose(1, 2, 0)
        if len(mask.shape) == 3:
            mask = mask.transpose(1, 2, 0)
        mask = cv2.resize(mask, self.maskresize, cv2.INTER_AREA)
        image = cv2.resize(image, self.imageresize, cv2.INTER_AREA)
        if len(image.shape) == 3:
            image = image.transpose(2, 0, 1)
        if len(mask.shape) == 3:
            mask = mask.transpose(2, 0, 1)

        return {'image': image,
                'mask': mask}


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample, maskresize=None, imageresize=None):
        image, mask = sample['image'], sample['mask']
        if len(mask.shape) == 2:
            mask = mask.reshape((1,)+mask.shape)
        if len(image.shape) == 2:
            image = image.reshape((1,)+image.shape)
        return {'image': torch.from_numpy(image),
                'mask': torch.from_numpy(mask)}


class Normalize(object):
    '''Normalize image'''

    def __call__(self, sample):
        image, mask = sample['image'], sample['mask']
        return {'image': image.type(torch.FloatTensor)/255,
                'mask': mask.type(torch.FloatTensor)/255}

# %%
class SegDataset(Dataset):
    """Segmentation Dataset"""

    def __init__(self, root_dir, imageFolder, maskFolder, transform=None, seed=None, fraction=None, subset=None, imagecolormode='rgb', maskcolormode='grayscale'):
        """
        Args:
            root_dir (string): Directory with all the images and should have the following structure.
            root
            --Images
            -----Img 1
            -----Img N
            --Mask
            -----Mask 1
            -----Mask N
            imageFolder (string) = 'Images' : Name of the folder which contains the Images.
            maskFolder (string)  = 'Masks : Name of the folder which contains the Masks.
            transform (callable, optional): Optional transform to be applied on a sample.
            seed: Specify a seed for the train and test split
            fraction: A float value from 0 to 1 which specifies the validation split fraction
            subset: 'Train' or 'Test' to select the appropriate set.
            imagecolormode: 'rgb' or 'grayscale'
            maskcolormode: 'rgb' or 'grayscale'
        """
        self.color_dict = {'rgb': 1, 'grayscale': 0}
        assert(imagecolormode in ['rgb', 'grayscale'])
        assert(maskcolormode in ['rgb', 'grayscale'])

        self.imagecolorflag = self.color_dict[imagecolormode]
        self.maskcolorflag = self.color_dict[maskcolormode]
        self.root_dir = root_dir
        self.transform = transform
        if not fraction:
            self.image_names = sorted(
                glob.glob(os.path.join(self.root_dir, imageFolder, '*')))
            self.mask_names = sorted(
                glob.glob(os.path.join(self.root_dir, maskFolder, '*')))
        else:
            assert(subset in ['Train', 'Test'])
            self.fraction = fraction
            self.image_list = np.array(
                sorted(glob.glob(os.path.join(self.root_dir, imageFolder, '*'))))
            self.mask_list = np.array(
                sorted(glob.glob(os.path.join(self.root_dir, maskFolder, '*'))))
            if seed:
                np.random.seed(seed)
                indices = np.arange(len(self.image_list))
                np.random.shuffle(indices)
                self.image_list = self.image_list[indices]
                self.mask_list = self.mask_list[indices]
            if subset == 'Train':
                self.image_names = self.image_list[:int(
                    np.ceil(len(self.image_list)*(1-self.fraction)))]
                self.mask_names = self.mask_list[:int(
                    np.ceil(len(self.mask_list)*(1-self.fraction)))]
            else:
                self.image_names = self.image_list[int(
                    np.ceil(len(self.image_list)*(1-self.fraction))):]
                self.mask_names = self.mask_list[int(
                    np.ceil(len(self.mask_list)*(1-self.fraction))):]

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        if self.imagecolorflag:
            image = cv2.imread(
                img_name, self.imagecolorflag).transpose(2, 0, 1)
        else:
            image = cv2.imread(img_name, self.imagecolorflag)
        msk_name = self.mask_names[idx]
        if self.maskcolorflag:
            mask = cv2.imread(msk_name, self.maskcolorflag).transpose(2, 0, 1)
        else:
            mask = cv2.imread(msk_name, self.maskcolorflag)
        sample = {'image': image, 'mask': mask}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
def get_dataloader(data_dir, imageFolder='Images', maskFolder='Masks', fraction=0.2, batch_size=4):
    """
        Create training and testing dataloaders from a single folder.
    """
    data_transforms = {
        'Train': transforms.Compose([ToTensor(), Normalize()]),
        'Test': transforms.Compose([ToTensor(), Normalize()]),
    }

    image_datasets = {x: SegDataset(data_dir, imageFolder=imageFolder, maskFolder=maskFolder, seed=100, fraction=fraction, subset=x, transform=data_transforms[x])
                      for x in ['Train', 'Test']}
    dataloaders = {x: DataLoader(image_datasets[x], batch_size=batch_size,
                                 shuffle=True, num_workers=8)
                   for x in ['Train', 'Test']}
    return dataloaders

# %%
def train_model(model, criterion, dataloaders, optimizer, metrics, bpath, num_epochs=3):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10
    # Use gpu if available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    # Initialize the log file for training and testing loss and metrics
    fieldnames = ['epoch', 'Train_loss', 'Test_loss'] + \
        [f'Train_{m}' for m in metrics.keys()] + \
        [f'Test_{m}' for m in metrics.keys()]
    with open(os.path.join(bpath, 'log.csv'), 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

    for epoch in range(1, num_epochs+1):
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-' * 10)
        # Each epoch has a training and validation phase
        # Initialize batch summary
        batchsummary = {a: [0] for a in fieldnames}

        for phase in ['Train', 'Test']:
            if phase == 'Train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            # Iterate over data.
            for sample in tqdm(iter(dataloaders[phase])):
                inputs = sample['image'].to(device)
                masks = sample['mask'].to(device)
                # zero the parameter gradients
                optimizer.zero_grad()

                # track history if only in train
                with torch.set_grad_enabled(phase == 'Train'):
                    outputs = model(inputs)
                    loss = criterion(outputs['out'], masks)
                    y_pred = outputs['out'].data.cpu().numpy().ravel()
                    y_true = masks.data.cpu().numpy().ravel()
                    for name, metric in metrics.items():
                        if name == 'f1_score':
                            # Use a classification threshold of 0.1
                            batchsummary[f'{phase}_{name}'].append(
                                metric(y_true > 0, y_pred > 0.1))
                        else:
                            batchsummary[f'{phase}_{name}'].append(
                                metric(y_true.astype('uint8'), y_pred))

                    # backward + optimize only if in training phase
                    if phase == 'Train':
                        loss.backward()
                        optimizer.step()
            batchsummary['epoch'] = epoch
            epoch_loss = loss
            batchsummary[f'{phase}_loss'] = epoch_loss.item()
            print('{} Loss: {:.4f}'.format(
                phase, loss))
        for field in fieldnames[3:]:
            batchsummary[field] = np.mean(batchsummary[field])
        print(batchsummary)
        with open(os.path.join(bpath, 'log.csv'), 'a', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerow(batchsummary)
            # deep copy the model
            if phase == 'Test' and loss < best_loss:
                best_loss = loss
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Lowest Loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
# Create the experiment directory if not present
if not os.path.isdir(bpath):
    os.mkdir(bpath)

hidden_layer = 256
NUM_CLASSES = 1
model_ft = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
in_features = model_ft.roi_heads.box_predictor.cls_score.in_features
in_features_mask = model_ft.roi_heads.mask_predictor.conv5_mask.in_channels
model_ft.roi_heads.box_predictor = FastRCNNPredictor(in_features, NUM_CLASSES)
model_ft.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, NUM_CLASSES)

for param in model_ft.parameters():
    param.requires_grad = False

# Specify the loss function
criterion = torch.nn.MSELoss(reduction='mean')
# Specify the optimizer with a lower learning rate
optimizer = torch.optim.Adam(model_ft.parameters(), lr=1e-4)

# Specify the evalutation metrics
metrics = {'f1_score': f1_score, 'auroc': roc_auc_score}



# Create the dataloader
dataloaders = get_dataloader(data_dir, batch_size=batchsize)
trained_model = train_model(model_ft, criterion, dataloaders, optimizer, bpath=bpath, metrics=metrics, num_epochs=epochs)

# Save the trained model
# torch.save({'model_state_dict':trained_model.state_dict()},os.path.join(bpath,'weights'))
torch.save(model, os.path.join(bpath, 'weights.pt'))
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100%|██████████| 178090079/178090079 [00:02<00:00, 78226791.65it/s]
# Epoch 1/5
# ----------
#   0%|          | 0/24 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c7c1ed0910d8> in <module>()
#      25 # Create the dataloader
#      26 dataloaders = get_dataloader(data_dir, batch_size=batchsize)
# ---> 27 trained_model = train_model(model_ft, criterion, dataloaders, optimizer, bpath=bpath, metrics=metrics, num_epochs=epochs)
#      28
#      29 # Save the trained model
#
# <ipython-input-7-f0aa697af68e> in train_model(model, criterion, dataloaders, optimizer, metrics, bpath, num_epochs)
#      34                 # track history if only in train
#      35                 with torch.set_grad_enabled(phase == 'Train'):
# ---> 36                     outputs = model(inputs)
#      37                     loss = criterion(outputs['out'], masks)
#      38                     y_pred = outputs['out'].data.cpu().numpy().ravel()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/detection/generalized_rcnn.py in forward(self, images, targets)
#      43         """
#      44         if self.training and targets is None:
# ---> 45             raise ValueError("In training mode, targets should be passed")
#      46         original_image_sizes = [img.shape[-2:] for img in images]
#      47         images, targets = self.transform(images, targets)
#
# ValueError: In training mode, targets should be passed
